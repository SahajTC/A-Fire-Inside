# %% [markdown]
# <a href="https://colab.research.google.com/github/SahajTC/Augmented-Financial-Intelligence/blob/main/Rating_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
sampl1=np.random.uniform(low=2,high=5,size=(50,))
sampl2=np.random.uniform(low=10,high=15,size=(50,))
print(sampl1[0])
# Out:
# 3.24131291162043

# %%
ra=1000
rb=1000
for i in range(0,50):
  print("Rating of A:",nr_a(sampl1[i],ra),"     Rating of B:",nr_a(sampl2[i],rb))
  ra=nr_a(sampl1[i],ra)
  rb=nr_a(sampl2[i],rb)
# Out:
# Rating of A: 1000.5498890595039      Rating of B: 999.4789765031023
# Rating of A: 1000.923961293768      Rating of B: 998.9526049421444
# Rating of A: 1001.17222679535      Rating of B: 998.6232802628731
# Rating of A: 1001.4223435118582      Rating of B: 998.1955083997884
# Rating of A: 1001.6063205081231      Rating of B: 997.708056690599
# Rating of A: 1002.0537353543268      Rating of B: 997.3697535587144
# Rating of A: 1002.3980260500199      Rating of B: 996.9057904701314
# Rating of A: 1003.0132244469906      Rating of B: 996.3507246214414
# Rating of A: 1003.2591392413859      Rating of B: 995.8751219984613
# Rating of A: 1003.5561884918252      Rating of B: 995.4169297494788
# Rating of A: 1004.2151174735318      Rating of B: 994.9199318014843
# Rating of A: 1004.5929836399517      Rating of B: 994.5691953469093
# Rating of A: 1005.0829112492497      Rating of B: 993.9866965978072
# Rating of A: 1005.3116711340911      Rating of B: 993.4089964463759
# Rating of A: 1005.8815012480858      Rating of B: 993.022511034525
# Rating of A: 1006.125630718428      Rating of B: 992.4494816553895
# Rating of A: 1006.8264339169018      Rating of B: 991.9268090663319
# Rating of A: 1007.0718553484393      Rating of B: 991.4184285885825
# Rating of A: 1007.5857941290978      Rating of B: 991.0851735103906
# Rating of A: 1008.2718941253123      Rating of B: 990.6250147898887
# Rating of A: 1008.7170314303853      Rating of B: 990.022557008019
# Rating of A: 1009.2361669189248      Rating of B: 989.551113698721
# Rating of A: 1009.4713508024734      Rating of B: 989.1739459013747
# Rating of A: 1009.9251278678269      Rating of B: 988.7986419877737
# Rating of A: 1010.373947249433      Rating of B: 988.241385854762
# Rating of A: 1010.6392734827928      Rating of B: 987.85902294168
# Rating of A: 1011.1666638067001      Rating of B: 987.5134743130028
# Rating of A: 1011.4507432956178      Rating of B: 987.1486639707488
# Rating of A: 1012.0983207212371      Rating of B: 986.8026644258501
# Rating of A: 1012.366745509385      Rating of B: 986.2983136150846
# Rating of A: 1012.9015035167726      Rating of B: 985.9063352163502
# Rating of A: 1013.4903925601348      Rating of B: 985.4084449330533
# Rating of A: 1013.7072376214098      Rating of B: 984.9784979934923
# Rating of A: 1014.1783983500629      Rating of B: 984.5270803606882
# Rating of A: 1014.9371938569327      Rating of B: 983.9213540093201
# Rating of A: 1015.4921703932021      Rating of B: 983.4034556014954
# Rating of A: 1015.9563012684354      Rating of B: 982.9069580356303
# Rating of A: 1016.3194824331378      Rating of B: 982.3556244680049
# Rating of A: 1016.6513947062107      Rating of B: 981.7826470059935
# Rating of A: 1017.2789454094353      Rating of B: 981.1995559193646
# Rating of A: 1017.6445701270403      Rating of B: 980.7363702733735
# Rating of A: 1017.9659906750094      Rating of B: 980.1596685369866
# Rating of A: 1018.2371325219831      Rating of B: 979.5732029068172
# Rating of A: 1018.4938361784637      Rating of B: 979.1342674825224
# Rating of A: 1019.2771114203949      Rating of B: 978.7132996952377
# Rating of A: 1019.8657920799477      Rating of B: 978.2380417868459
# Rating of A: 1020.2977693069557      Rating of B: 977.6427731993695
# Rating of A: 1020.7537416585391      Rating of B: 977.1531925562609
# Rating of A: 1021.3414103671956      Rating of B: 976.5644334123757
# Rating of A: 1022.0261516834136      Rating of B: 976.0754851308317

# %%
def expected_score_a(ra):
   y=(1/(1+10**((100-ra)/4)))
   return y-12.5

def nr_a(score_a,oldr_a):
  return oldr_a+2*(score_a-(expected_score_a(oldr_a)))

# %%
ra=100
rb=100
dr=100
size=5000
sampla=np.random.uniform(low=2,high=5,size=(size,))
samplb=np.random.uniform(low=10,high=15,size=(size,))
arr=np.array([])
arr2=np.array([])
arr3=np.array([])
arr4=np.array([])
for i in range(0,size):
  ra=nr_a(sampla[i],ra)
  rb=nr_a(samplb[i],rb)
  dr=nr_a(12.5,dr)
  arr=np.append(ra,arr)
  arr3=np.append(rb,arr3)
  arr2=np.append(i,arr2)
  arr4=np.append(dr,arr4)
df=pd.DataFrame()
arr4=arr4/100
df["ratings_a"]=arr/arr4
df["ratings_b"]=arr3/arr4
df["default"]=arr4
df["index"]=arr2
for i in range(1,25):
  print(i,") Rating of A: ",df["ratings_a"][i]," Rating of B: ",df["ratings_b"][i])
plt.plot(df["index"],df["ratings_a"],'--r',df["index"],df["ratings_b"],'--g')
# Out:
# 1 ) Rating of A:  62.54003884325062  Rating of B:  100.00864854091671
# 2 ) Rating of A:  62.54012393281858  Rating of B:  100.00835244393903
# 3 ) Rating of A:  62.5396359621697  Rating of B:  100.00893880129661
# 4 ) Rating of A:  62.54063100124298  Rating of B:  100.00820916157342
# 5 ) Rating of A:  62.54044476430497  Rating of B:  100.00705027155334
# 6 ) Rating of A:  62.54003285103015  Rating of B:  100.00805147578488
# 7 ) Rating of A:  62.53959795995387  Rating of B:  100.0092881522057
# 8 ) Rating of A:  62.53961112003769  Rating of B:  100.01110357229615
# 9 ) Rating of A:  62.53944725355321  Rating of B:  100.01208957447305
# 10 ) Rating of A:  62.53931941160345  Rating of B:  100.01219668311423
# 11 ) Rating of A:  62.54046782183497  Rating of B:  100.01068381910453
# 12 ) Rating of A:  62.53950701855036  Rating of B:  100.0102234382075
# 13 ) Rating of A:  62.53928637121968  Rating of B:  100.00970577547696
# 14 ) Rating of A:  62.53975478345491  Rating of B:  100.0106253998172
# 15 ) Rating of A:  62.54075722717548  Rating of B:  100.00862990216461
# 16 ) Rating of A:  62.54069747429778  Rating of B:  100.00786328399828
# 17 ) Rating of A:  62.539762935133645  Rating of B:  100.00855142089348
# 18 ) Rating of A:  62.54023260332101  Rating of B:  100.00963472233515
# 19 ) Rating of A:  62.539318067085524  Rating of B:  100.0109229595798
# 20 ) Rating of A:  62.54055157576827  Rating of B:  100.01026521209911
# 21 ) Rating of A:  62.541537646611644  Rating of B:  100.01056619861282
# 22 ) Rating of A:  62.541694485971014  Rating of B:  100.00926555645921
# 23 ) Rating of A:  62.54161000151053  Rating of B:  100.0109127757456
# 24 ) Rating of A:  62.54044986117346  Rating of B:  100.01227634306571
# [<matplotlib.lines.Line2D at 0x7f08f4c44640>,
#  <matplotlib.lines.Line2D at 0x7f08f4c444f0>]

# %%
def expected_score_a(ra):
   y=(1/(1+10**((100-ra)/4)))
   return y-12.5

def nr_a(score_a,oldr_a):
  return oldr_a+25*(score_a-(expected_score_a(oldr_a)))

# %%
def plot_rate(LOW,HIGH,size=50):
  ri=100
  dr=100
  sampl=np.random.uniform(low=LOW,high=HIGH,size=(size,))
  ##sampl1=np.random.uniform(low=2,high=5,size=(2000,))
  ##sampl=np.append(sampl,sampl1)
  arr=np.array([])
  arr4=np.array([])
  for i in range(1,size):
      ri=nr_a(sampl[i],ri)
      dr=nr_a(12.5,dr)
      arr=np.append(arr,ri)
      arr4=np.append(arr4,dr)
  arr4=arr4/100
  arri=np.array([])
  for i in range(1,size):
    arri=np.append(arri,i)
  arr=arr/arr4
  return arr

# %%
df=pd.DataFrame()
arri=np.array([])
size=500
for i in range(1,size):
    arri=np.append(arri,i)
df["index"]=arri
df["2-5"]=plot_rate(2,5,size)
df["5-10"]=plot_rate(7.5,7.5,size)
df["10-15"]=plot_rate(10,15,size)
df["15-25"]=plot_rate(15,25,size)
df["25-35"]=plot_rate(25,35,size)
df["35-45"]=plot_rate(35,45,size)
df["45-55"]=plot_rate(45,55,size)
df["55-70"]=plot_rate(55,70,size)
df["70-85"]=plot_rate(70,85,size)
df["85-100"]=plot_rate(85,100,size)
df["base"]=plot_rate(0,0,size)

# %%
df.head(20)
# Out:
#     index        2-5       5-10       10-15       15-25       25-35  \
# 0     1.0  65.777087  82.456140   97.067945  134.422249  157.190830
# 1     2.0  64.661114  80.952381  100.898228  129.370313  172.798271
# 2     3.0  62.151341  80.392157  100.608239  126.690273  166.823200
# 3     4.0  61.989411  80.099502   99.226382  128.939603  169.767116
# 4     5.0  62.649807  79.919679  100.254701  130.121728  173.058860
# 5     6.0  63.227392  79.797980  101.490386  130.848535  175.618362
# 6     7.0  62.690652  79.710145  101.842395  129.180939  175.064503
# 7     8.0  63.403570  79.643766  102.071203  130.974615  172.839531
# 8     9.0  63.420649  79.591837  101.190000  129.175829  174.906937
# 9    10.0  63.447653  79.550102  100.334557  127.620862  175.159112
# 10   11.0  63.076922  79.515829  100.223553  126.187580  173.705154
# 11   12.0  63.020255  79.487179  100.603067  127.682138  173.742683
# 12   13.0  62.645255  79.462875  101.189358  128.272150  172.286248
# 13   14.0  62.442318  79.441997  100.510134  129.521905  173.219551
# 14   15.0  62.371094  79.423868  100.138710  130.247754  173.445156
# 15   16.0  62.421703  79.407979  100.717745  129.996660  174.420252
# 16   17.0  62.518996  79.393939  101.103627  130.313401  174.441869
# 17   18.0  62.435848  79.381443  100.613094  130.432487  174.533810
# 18   19.0  62.383300  79.370250  100.511019  131.381415  175.396012
# 19   20.0  62.644172  79.360165  100.586236  130.799122  176.126108
#
#          35-45       45-55       55-70       70-85      85-100       base
# 0   198.595187  247.940484  289.811694  327.898650  384.789550  56.140351
# 1   202.080117  249.257730  304.855998  351.689091  417.137828  52.380952
# 2   202.199844  257.894977  307.598138  349.864896  412.554851  50.980392
# 3   202.958529  258.694077  311.546978  357.333356  411.438715  50.248756
# 4   206.144024  254.921021  305.860543  360.310557  417.175710  49.799197
# 5   204.895349  251.890718  307.037201  359.829647  415.309295  49.494949
# 6   206.898665  250.809695  305.187160  364.118523  419.584922  49.275362
# 7   209.088675  249.168625  303.245015  368.713520  424.616744  49.109415
# 8   208.731606  251.511967  305.704110  367.537511  423.283192  48.979592
# 9   207.471889  253.246146  306.263371  367.763439  425.763642  48.875256
# 10  209.579237  251.814737  304.181845  367.494153  428.901301  48.789572
# 11  209.780814  252.565358  305.784776  367.248461  430.465130  48.717949
# 12  208.625754  251.879729  306.124131  365.738001  431.285010  48.657188
# 13  209.864650  252.379807  304.104318  364.186985  429.668389  48.604993
# 14  210.364102  253.702597  302.456393  365.559334  431.837883  48.559671
# 15  209.936896  253.627563  300.977088  367.692013  430.603975  48.519949
# 16  209.377466  253.584186  299.657804  366.231908  430.447449  48.484848
# 17  208.770341  252.690183  300.181719  367.160364  430.384983  48.453608
# 18  209.136191  252.068596  299.188471  366.534405  429.088996  48.425624
# 19  208.942788  252.567702  301.131733  367.795839  430.845800  48.400413

# %%
plt.plot(df["index"],df["2-5"],'--g',df["index"],df["5-10"],'--g',df["index"],df["10-15"],'--g',df["index"],df["15-25"],'--g',df["index"],df["25-35"],'--g',df["index"],df["35-45"],'--g',df["index"],df["45-55"],'--g',df["index"],df["55-70"],'--g',df["index"],df["70-85"],'--g',df["index"],df["85-100"],'--g',df["index"],df["base"],'--r');
